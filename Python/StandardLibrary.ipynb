# %% [markdown]
# Standard Library

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
## random
import random 
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 7
# cherry

# %%
## File and directory accesss 
import os
print(os.getcwd())
# Out:
# c:\Users\t0283179\AI\Python

# %%
os.mkdir('test_dir')

# %%
## High level operations on files
import shutil
shutil.copyfile('Hello.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization 
import json
data={'name':'sid','age':'25'}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data=json.loads(json_str)
print(parsed_data)
# Out:
# {"name": "sid", "age": "25"}
# <class 'str'>
# {'name': 'sid', 'age': '25'}

# %%
## csv create 

import csv 
## write mode 
with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['siddharth','25'])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['siddharth', '25']

# %%
## date time 
from datetime import datetime,timedelta
now=datetime.now()
print(now)

yesterday = now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-05-24 00:17:30.176132
# 2026-05-23 00:17:30.176132

# %%
## time 
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1779562094.1568882
# 1779562096.159103

# %%
## regular expression 
import re
pattern=r'\d+'
text="siddharth 15 singh"
match=re.search(pattern,text)
print(match.group())
# Out:
# 15
